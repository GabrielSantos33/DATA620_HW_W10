# %% [markdown]
# ## Data620 Assignment: Document Classification
# #### Gabriel Santos
# #### Date: 03-28-2023

# %% [markdown]
# It can be useful to be able to classify new "test" documents using already classified "training" documents.  A common example is using a corpus of labeled spam and ham (non-spam) e-mails to predict whether or not a new document is spam.  Here is one example of such data: [UCI Machine Learning Repository: Spambase Data Set](http://archive.ics.uci.edu/ml/datasets/Spambase)
#
# For this project, you can either use the above dataset to predict the class of new documents (either withheld from the training dataset or from another source such as your own spam folder).
#
# For more adventurous students, you are welcome (encouraged!) to come up a different set of documents (including scraped web pages!?) that have already been classified (e.g. tagged), then analyze these documents to predict how new documents should be classified.

# %% [markdown]
# ### Corpus selection

# %% [markdown]
# Let's choose the gutenberg corpus texts.

# %%
import nltk
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\tqkar\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
import nltk
import random
random.seed(200)
import pandas as pd
pd.set_option('display.max_rows', 400)
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# I chose the following books:
#
# - Books by shakespeare (Caesar, Hamlet and Macbeth)
# - Poems by Blake
#
# The objective is to be able to determine who wrote a phrase or a specific passage.

# %% [markdown]
# ### 1. Compare Shakespeare vs Blake

# %% [markdown]
# The first step is to take all three of Shakespeare's plays and combine them to create a single text. Then we'll convert all to lowercase to remove duplicate words. We will also remove punctuation. Then we create a list of text segments. Each segment will have an extension of 800 words.

# %%
shakespeare = nltk.corpus.gutenberg.words('shakespeare-caesar.txt')+nltk.corpus.gutenberg.words('shakespeare-hamlet.txt')+nltk.corpus.gutenberg.words('shakespeare-macbeth.txt')
shakespeare = [word.lower() for word in shakespeare if word.isalpha()]
shakespeare1=[]
for i in range(87):
    shakespeare1.append([shakespeare[i*800:(i+1)*800],'shak'])
len(shakespeare)
# Out:
# 69340

# %%
len(shakespeare1)
# Out:
# 87

# %% [markdown]
# We now have a list of 87 segments each with 800 words, for Shakespeare.

# %% [markdown]
# Now with Blake's text, we'll convert everything to lowercase to eliminate duplicate words. We will also remove punctuation. Then we create a list of text segments. Each segment will have an extension of 800 words.

# %%
blake = nltk.corpus.gutenberg.words('blake-poems.txt')
blake = [word.lower() for word in blake if word.isalpha()]
blake1=[]
for i in range(9):
    blake1.append([blake[i*800:(i+1)*800],'blak'])
len(blake)
# Out:
# 6934

# %%
len(blake1)
# Out:
# 9

# %% [markdown]
# We now have a list of 9 segments each with 800 words, for Blake. We have fewer segments because the number of words is less.

# %% [markdown]
# ### 2. Feature
#
# We are going to join the two generated lists (Shakespeare and Blake ), in one. Then we are going to identify the 2000 most frequent words. To then be able to create a list that allows us to use them as a text classifier.

# %%
sb=shakespeare+blake
all_words = nltk.FreqDist(w.lower() for w in sb)
word_features = list(all_words)[:2000] 

wlist = []
for i in range(0, 2000, 200):
    df = pd.DataFrame(word_features[i:(i+200)])
    df.columns=['200 words']
    wlist.append(df)

pd.concat(wlist, axis=1)
# Out:
#     200 words  200 words      200 words    200 words    200 words  \
# 0         the       euen             la        touch         vile
# 1         and     nature           ouer      musicke          arm
# 2          to      still           dost     flourish      already
# 3           i       hold            fit     patience        crown
# 4          of       wife           alas         land       proofe
# 5           a        pol          giuen        awake        reade
# 6         you      rosse         crowne    iudgement        faces
# 7          my        ant           vnto         gaue         lyes
# 8          in        off          lesse       greefe       season
# 9        that       once           meet        whole        braue
# 10         is      beare          houre       seemes    presently
# 11         it       true       madnesse         read        shine
# 12        not       does            cas          fly          red
# 13          d      peace          alone       royall       feares
# 14        his      whose       together       honour        issue
# 15       with      while         honest      comming       silent
# 16        for        two           sure         rose            m
# 17         me     though           send        twere         wept
# 18       this       many        purpose     gracious         writ
# 19        but        set            woe         gold         deny
# 20         he       face          power    lucillius        foole
# 21       your       name          neere         song        weary
# 22         be       liue       question       alarum        naked
# 23       what       euer         pardon      thankes        deepe
# 24       haue        way          seeme        image       damned
# 25        him      poore          watch       tender     soldiers
# 26         so      earth           yong        mercy         hill
# 27         as      heard        fortune       golden         barn
# 28       will     sleepe          guild         upon    marcellus
# 29        our       exit         cawdor          its         bell
# 30        all    against           down        ought       sister
# 31          s      rosin          walke        truly     blessing
# 32       thou     indeed           look       course       braine
# 33        ham   himselfe       generall       portia      chamber
# 34        are      sword         vertue        sooth         guil
# 35         we     queene          helpe           em    highnesse
# 36         on        old             ye        stood       thence
# 37      shall      finde         rather         fare      pyrrhus
# 38         no    thought           pale        throw     innocent
# 39       then      words          right      brought       virgin
# 40         do      first        players       action          mac
# 41       lord       part          dayes       stirre       duncan
# 42         by     friend        brother     metellus        murth
# 43       they      soule         hither          yes      seyward
# 44         if        bed        morning      offence       heaven
# 45       come    horatio           mark         grow      respect
# 46      enter       rome          winde        tooke   conscience
# 47        thy       else          faith       sweare        knaue
# 48       king      keepe       denmarke        caius       danger
# 49        was       caes       polonius      whether        leade
# 50       from       word          graue      valiant       cruell
# 51        let       fire           doct       knowes      patient
# 52       good      hands           hope     wisedome       vanish
# 53       thee    welcome          march       thanke      speakes
# 54        now     banquo          speak       hearke       forget
# 55      there     follow           late          bin        lacke
# 56      their    caesars          seeke      country        angry
# 57         or       cask         common          ioy       honors
# 58          o     better          yours         wood      masters
# 59         at       here           went       blacke       growne
# 60        did      polon          marry        bound         glad
# 61       like       gone         almost   fortinbras         brow
# 62     caesar     matter          newes     gertrude        quite
# 63      which       brut        heauens        lords      because
# 64       know        eye         knowne        queen       effect
# 65       when      place         strong          act           ne
# 66         vs         re       betweene         maid      silence
# 67       them       none         desire       spring        holds
# 68       more     tongue           wilt        takes        slaue
# 69        her        ere          doubt     sleeping        women
# 70      would      marke      gentlemen       reynol          bar
# 71        how       rest           care         anon         open
# 72       vpon        goe          fight      husband    dreadfull
# 73     brutus       gods         ground         gent      natures
# 74      where     spirit           sent       pretty         saue
# 75         am      sonne          messa     malcolme       dagger
# 76       well       stay        delight        actus      deliuer
# 77        bru    laertes          kings          mur         foot
# 78        why    without        command         knew       cymber
# 79          t        nay          voice        weepe         sits
# 80     should        cry         hearts        among       dreame
# 81        man      seene           holy       toward        doore
# 82       hath        saw          loues        mouth        sunne
# 83        may      light         romans        offer         past
# 84      selfe      caska          sound          cut      commend
# 85        who    strange          times      mothers     ligarius
# 86      night     meanes           high     ambition          dew
# 87        yet       said         smiles          sea         wise
# 88        say      cause          laugh       tyrant       beauty
# 89       macb       best          kinde        begin      comfort
# 90         an      after         bright        least        peece
# 91      heere  therefore          truth         mans         seen
# 92       must       body       daughter        halfe        beast
# 93        see       ayre        seruant         fast     straight
# 94       most      forth          haile            y       chance
# 95        tis       full          false        deare      sodaine
# 96        too      bring          madam         cato        ready
# 97         th      being         master        noise        ranke
# 98       make        bid          foule     traitors        pitty
# 99       time   thoughts      something      prythee     funerall
# 100    speake      deere           octa        begge          hot
# 101      loue      beene           sing     brothers     offended
# 102      such     morrow            osr        bones           de
# 103      giue        sit       macduffe         ring       memory
# 104       one        boy          child         moue      treason
# 105       out       each       capitoll     pindarus           dy
# 106       sir        mar         decius       slaine         poet
# 107       had      honor            run    goodnight        teare
# 108        st       last          shake    gentleman      sisters
# 109     these      three            age         bore     souldier
# 110      were        end           note     scotland       horses
# 111       day      thine          smile        black          pay
# 112       can      ghost     themselues        tears   attendants
# 113        go        get         second     directly        field
# 114     cassi     answer        thunder         safe       former
# 115       ile        vse           left      beseech         tane
# 116      some       free          voyce    wherefore       strato
# 117       doe       came        spirits        weare         hora
# 118       men      house          found        worse       return
# 119        oh        clo         breake        passe       gainst
# 120    hamlet       love     honourable      appeare       garden
# 121      tell      hence        weeping       cicero        songs
# 122       nor       long        reuenge         turn       phrase
# 123       hor    further          shalt      trouble          gho
# 124        vp    another          knock        loose        court
# 125      mine     selues            ill        think           ah
# 126     death      faire         double        spoke     knocking
# 127    father        lay  guildensterne         bold     maiestie
# 128     heare       fell          white    ambitious         bene
# 129   cassius   farewell            son        burne         snow
# 130      much        luc            sey       bosome         ones
# 131     feare      happy           hear         cast         feed
# 132      done      wrong          every       change          ban
# 133       she    ophelia           have     pleasure       doctor
# 134     looke    england          never          led          ten
# 135     heart      lenox            mee        close      english
# 136      away       home             ho    trebonius      macduff
# 137      hand      grace           wish       strike       fleans
# 138     great       fall      dangerous      mortall        arise
# 139    thinke      since          point        along        vales
# 140      till        new          sicke       stands         deep
# 141      take      borne        present       secret         pity
# 142    exeunt      meane         nights         arme         lyca
# 143    antony      minde          roman        talke     tragedie
# 144      very     please           hang        going        stage
# 145      thus      sleep          forme       keepes          yea
# 146    againe     bloody          giues      publius        needs
# 147      life       deed          birds        enemy   countrymen
# 148     could      onely         beares        blame        fault
# 149      doth     worthy            por         wine       mettle
# 150    little    beleeue        withall      returne      towards
# 151     noble      state           whom        merry         wing
# 152       art    through           fled          lou        noyse
# 153      both       eare          liues       making       beware
# 154    mother   children       villaine         hart        order
# 155     downe      cinna          cloud      custome  countenance
# 156      made     lucius           thel         lies         iust
# 157    heauen     reason          green      daggers       become
# 158     stand        lye             er         tent        breed
# 159        qu        mad         infant        angel     consider
# 160   macbeth     sorrow          human        horse         ease
# 161     blood       flye       certaine     philippi        durst
# 162      dead     gentle          armes         duty        aliue
# 163      lady       cold           draw    messenger          wit
# 164     leaue       hell          sayes      seruice       mindes
# 165    cannot       goes          turne      maiesty     seuerall
# 166      laer      round        passion        dread          met
# 167      owne    murther         people    excellent     naturall
# 168      into      makes          meete          top         walk
# 169      macd     speech        fashion        table       wonder
# 170        ha    messala         lookes         wild       fooles
# 171    before      scena           fear  rosincrance      tyrants
# 172     thing        mal         thrice        verie       griefe
# 173     sweet      thane           told       poyson     terrible
# 174       put        joy           soft         worm         gate
# 175      play        bad          young        trade      content
# 176      ophe     fellow          eares         fine       bestow
# 177       any       same           hide      streets         next
# 178     other     drinke            ore        feast         need
# 179       hee      vnder           rise        aboue          hoe
# 180   nothing       lost         health   calphurnia        often
# 181      call    fathers            ser         cass         seek
# 182      eyes      sight         mighty        warre         drop
# 183   friends      farre          shame       shewes       steele
# 184       god       kill       thousand       buried      dreames
# 185     neuer       dare        receiue        start        fetch
# 186     those       banq        letters       diuell      merrily
# 187      head       weep          water        weake      braines
# 188      shew      worke         charge          has      neither
# 189     might   remember         report      thinkes        shape
# 190     about   titinius            kin       behold     marriage
# 191     euery     enough            sun         twas        dwell
# 192    things      backe           tree        worth        visit
# 193     comes        bee           malc   enterprize        gowne
# 194      pray     breath           lamb      wherein        yeeld
# 195    within        dye         soules       clouds      prepare
# 196         l      woman           hard      besides        harme
# 197     world  businesse            oft         bird       heeles
# 198      hast   octauius        flowers      reasons      lepidus
# 199       wee      youth         teares         base       humble
#
#        200 words     200 words    200 words     200 words    200 words
# 0      satisfied          feet     eternall         sheep         hate
# 1          flesh          mild       plucke     alexander        anger
# 2        liberty          dark        fiery        priest      earnest
# 3           dust         grass   conference        deuill     generals
# 4     instrument        itself        chanc       osricke     touching
# 5         beside        proper          sad     carriages      tydings
# 6         wounds       indeede         aske        foyles         mess
# 7        enemies        stones       manner          toth     addition
# 8            doo       infants        faine         title        waste
# 9        buriall         shout      falling        attend        twixt
# 10           try      pompeyes       amisse      hostesse         forc
# 11           ple         curse        foure        horror       repose
# 12          fill        presse      schoole           len      farwell
# 13       hearing          ides         puts      cauldron          var
# 14        forgot       desires         wait         armed         cals
# 15       thither       obserue        firme         babes    otherwise
# 16        hauing        choose         seat          nest         tune
# 17         teach       subiect    lightning        modest      reading
# 18          army        single  destruction         fiend   apparition
# 19        growes           fed        flame      laughing       powres
# 20         worst      sometime         lyon       evening      courage
# 21          obey          wide      hundred         lambs       threat
# 22         canst        whiles       crosse        around     shadowes
# 23           mes       neyther      tremble          soon         lowd
# 24         sides      thinking  instruments       pitying   discomfort
# 25          ride         third    fearefull          lion        torch
# 26     volumnius        market       limbes          year         stra
# 27      barnardo        throat      therein            us      soldier
# 28          fran         taken      willing        winter        twill
# 29          fate       wrought      answere          lily       figure
# 30        throne       opinion      noblest          fade         work
# 31         beard          sway       sights          rule       cannon
# 32          damn          want        winne           cob       motiue
# 33         cries        beasts       statue          mend     violence
# 34          been     monstrous    encounter         sawcy      summons
# 35          sigh          bond        sting        shooes      heerein
# 36       violent         haste        abuse       recouer    attendant
# 37        others          ours   greatnesse      conquest   discretion
# 38           hoa        turnes        slept        pompey    imperiall
# 39         maker       preuent       natiue   battlements        scale
# 40          shee          seal      betimes       chimney      affaire
# 41          ment        letter       spurre          sate    cornelius
# 42         small        motion       pricke         runne        sence
# 43        church        visage        count        plague        wants
# 44       witches         yeare    doubtfull        images         salt
# 45        summer          oath       terror    ceremonies   incestuous
# 46     dunsinane         neede   flatterers         driue       thrift
# 47          morn        guilty       humour        pluckt       tables
# 48          form          acte        faile          view       goodly
# 49          over        clocke        fresh        barren     appeares
# 50         prima         maine     purposes      ceremony         slow
# 51          idle        resolu      asleepe          wont         kept
# 52       matters          bent     stronger        number     troubles
# 53           mou         stole          cai          sees          toe
# 54      perceiue        supper    vouchsafe    reflection          few
# 55        thicke           ask       iulius     immortall      station
# 56         speed         foote        dying      troubled          key
# 57         manet        vnfold       beyond         flood          ist
# 58        quicke       secrets          apt        yonder         baby
# 59       perhaps     sometimes      foolish         aside        bloud
# 60        shadow        giuing       paines      creature        heate
# 61        fauour        horrid       houres         cried    breathing
# 62        endure        seeing        trust        feeble        pious
# 63      wretched        foorth       womans        narrow  imagination
# 64          bend          deci       sickly          huge       direct
# 65        coward           loe       neerer         peepe       forbid
# 66        colour         fears         seru         fates      serpent
# 67         write         teeth        sirra       coniure         lust
# 68       starres      followes      quality         feede        milke
# 69         weigh       leysure      prayers          ayme        sinne
# 70         heauy           low       starre    heereafter         host
# 71         soone       painted        skies       intreat     reynoldo
# 72         roome        twenty         dyes          spot        drift
# 73      senators        depart       pulpit          glow    knowledge
# 74           fat       strooke       mutiny       alwayes       wanton
# 75         deeds       conceit        deede         pleas       closes
# 76          mock      presence    pleasures           ope       gather
# 77       greater        regard     vnknowne          stab       breefe
# 78         meere         rites        sport         blunt        assay
# 79       fingers     discourse       safely     execution       awhile
# 80     sicknesse          lend       falles         likes        proue
# 81     according         iudge     bleeding         humor      mistris
# 82         heads        praise       marcus           cic     honestie
# 83        promis        stuffe       greeue         swell       begger
# 84          rage         haire     modestie       torches     heauenly
# 85          held          shot      becomes      sensible         shal
# 86        faults           wel    aduantage     yesterday     argument
# 87          seem         feele         post         stone      cunning
# 88         tempt       greefes       safety        ghosts         line
# 89          dull           wil       demand     personall       rugged
# 90      strength        abroad         sake           yee     murthers
# 91          tale      answered       findes        serues        priam
# 92      redresse           die        euill   indifferent   rebellious
# 93   consequence          asse    faithfull         parts       sticke
# 94       walking      treasure        seale       lighted       hecuba
# 95       whereto        powers      descend        graunt      gonzago
# 96       promise         lucil          ran           dis         warm
# 97        knocke        receiu        pluck         taper     confound
# 98      kingdome       iustice       doores             c     ignorant
# 99         darke         mirth       reueng          rous         pate
# 100          cin         sorry      traitor  conspirators         nose
# 101     confesse        breast      married          east   affliction
# 102       valour         loued         fold          grey      beautie
# 103          buy      marching       hollow         lines       sooner
# 104         mens        enemie        guard       tyranny      nunnery
# 105        wrath     souldiers     practice       cowards      quickly
# 106        bleed         force     possible       honesty         keep
# 107     seruants     affection         rash        causes       ladies
# 108         eate         birth      legions        siluer         plac
# 109     wholsome          prey          cup           rul     speciall
# 110       charme          lose        doing           hew      hoboyes
# 111        vowes      remaines      defence     necessary     prologue
# 112          bow          clit          tit       company      shortly
# 113     successe        saying       sought          treb         ends
# 114       senate        twelue       angell      fantasie        keene
# 115      smiling          dane          com        betray        rises
# 116         side    particular        hopes         trees        easie
# 117        suite          sore     battaile         eight      forgiue
# 118       cheere        norway       blowes    constancie      effects
# 119       person       trumpet     witnesse        drawes       repent
# 120       swords   remembrance    slaughter       fearing      passage
# 121         wash        freely      vnlesse       embrace          rat
# 122       liuing          show       fatall          sixe        front
# 123     fortunes        duties         push         seuen         vice
# 124         rich         vnkle        titin         wound     precious
# 125         whil   disposition       whilst      husbands      contend
# 126        wayes           cap       lights        render      disease
# 127       either       warrant     prisoner        browes       dismay
# 128      consent        tertia          owe      opinions       wormes
# 129        dumbe          tend       clitus       battell         cure
# 130        began  circumstance       office         taste      springs
# 131     audience        maiden         prou          knee      tongues
# 132       cursed             n         dyed          lest      applaud
# 133         poor          wits        twice       priuate          fac
# 134       wisely       instant         pole          pure        folly
# 135         tear       extasie       norwey         euils        spade
# 136         stop          amen        lands        vision      ancient
# 137         drum         liege        cocke       affraid       builds
# 138       appear       whereon       aduice         cynna     gallowes
# 139        moone    commission       greene        defend     absolute
# 140          liu         short     dispatch         doest    strangely
# 141         back           hid       france     mountaine          woo
# 142        booke        french        cosin      counsell         runs
# 143      claudio           own      dearest           aye         only
# 144         sirs        suffer       length         grant        oddes
# 145     lordship     christian         edge      constant       affear
# 146       heauie        danish       humbly         lowly        heath
# 147         wake        blesse        catch      freedome        calls
# 148      behinde          babe      beguile          fixt       glamis
# 149         blow         sense       moment     proclaime      partner
# 150        begun           got    desperate         abide          ang
# 151      alarums         wager         lead          amaz       glamys
# 152       childe         drown       prison        yeares       quarta
# 153          foe         scull        wings       benefit     approach
# 154    countries          nine        gifts        louing     macbeths
# 155         sold       perfect      seeming        deseru       castle
# 156         list        drumme         adue     pittifull           le
# 157          pit         angus   distracted        points      fleance
# 158       labour        thanes       remoue        coarse   murtherers
# 159        quiet         powre        dream       tearmes         fife
# 160      warlike        porter        wilde       forrest       flight
# 161          law        desert        meant         liued       scaena
# 162      secunda        seyton   soueraigne     prophesie       bubble
# 163        frame          book        dutie          lips       tigers
# 164      meeting        filled    distemper     vtterance        blown
# 165       whence          hair    obedience      familiar        appar
# 166       graces          live        vilde         serue      cruelty
# 167        spend          near       prince     plebeians         pull
# 168          fie           tom       bodies       numbers      byrnane
# 169       longer            up       thanks       publike        blake
# 170       wicked           air     delights      countrey      valleys
# 171    perchance        divine         pace       censure        hears
# 172         bear          vain       player        slaues        under
# 173   vnderstand          born        carry         pause           ll
# 174         mind       william      dismall         reply       rising
# 175       angels       flauius       spoken        begins        gives
# 176     horrible     creatures      sleepes       closset      blossom
# 177        didst         signe      burning     villaines        bosom
# 178   vnnaturall           fla         gall       compell         ever
# 179        swift       triumph         shut       summers       lovely
# 180      hamlets        brings       scorne      followed        dress
# 181     pleasant         tyber       finger         burst         girl
# 182       sonnes        houses        guilt        formes         days
# 183            e         knees       leaues         gates        grief
# 184         bare          sort       kisses      breefely      selfish
# 185       drowne         kisse         food         share      eternal
# 186     fellowes          calp       estate     corporall         ways
# 187         pipe       antonio    pronounce        taught      parents
# 188      destroy         brest        drink      property        tired
# 189         find        glasse      vantage      officers         weak
# 190        broke        impart        broad        gently     youthful
# 191         clay       outward          ene        taking     helpless
# 192          hit         story     fighting       offices          sat
# 193      colours           awe         owle         space       mortal
# 194   donalbaine         saide          don         dogge       valley
# 195        tiger      speeches          due         break          har
# 196       flower        temper       became         venom  shakespeare
# 197         heat         palme     performe         raise       primus
# 198    trembling        graues        sings         locke       scoena
# 199        shade        walkes        guest         learn    carpenter

# %% [markdown]
# We are going to use the function the Natural Language Processing with Python textbook on page 228 to create a function generator that uses the list of the 2000 most frequent words and indicates whether or not each word is present in the text as a function.

# %%
def document_features(document): 
    document_words = set(document) 
    features = {}
    for word in word_features:
        features['contains({})'.format(word)] = (word in document_words)
    return features

# %% [markdown]
# Let's perform the test on the complete text of Blake.

# %%
features = document_features(blake)
list(features.items())[:20]
# Out:
# [('contains(the)', True),
#  ('contains(and)', True),
#  ('contains(to)', True),
#  ('contains(i)', True),
#  ('contains(of)', True),
#  ('contains(a)', True),
#  ('contains(you)', True),
#  ('contains(my)', True),
#  ('contains(in)', True),
#  ('contains(that)', True),
#  ('contains(is)', True),
#  ('contains(it)', True),
#  ('contains(not)', True),
#  ('contains(d)', True),
#  ('contains(his)', True),
#  ('contains(with)', True),
#  ('contains(for)', True),
#  ('contains(me)', True),
#  ('contains(this)', True),
#  ('contains(but)', True)]

# %% [markdown]
# ### 3. Create Test Train Dataset
#
# We are going to create a single list with all the segments of Shakespeare and Blake. to create the text corpus that we will use to train and test our classifier model.

# %%
documents = shakespeare1+blake1

# %% [markdown]
# Training and testing a classifier for document classification:

# %%
import random
random.shuffle(documents)
featuresets = [(document_features(d), c) for (d,c) in documents]
len(featuresets)
# Out:
# 96

# %% [markdown]
# We split our dataset into test and training sections, train our classifier on the training set, and check the accuracy of our model on the test set.

# %%
train_set, test_set = featuresets[:50], featuresets[50:]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 1.0

# %% [markdown]
# According to the result it is easy for NLTK to distinguish between Shakespeare and Blake.

# %% [markdown]
# ### We are going to include more authors to test: Adding Stories by Bryant

# %%
bryant = nltk.corpus.gutenberg.words('bryant-stories.txt')
bryant = [word.lower() for word in bryant if word.isalpha()]
bryant1=[]
for i in range(46):
    bryant1.append([bryant[i*1000:(i+1)*1000],'brya'])
len(bryant)
# Out:
# 46611

# %%
sbb=shakespeare+blake+bryant
all_words = nltk.FreqDist(w.lower() for w in sbb)
word_features = list(all_words)[:2000] 

documents=shakespeare1+blake1+bryant1

# %% [markdown]
# Training and testing a classifier for document classification:

# %%
random.shuffle(documents)
featuresets = [(document_features(d), c) for (d,c) in documents]
len(featuresets)
# Out:
# 142

# %%
train_set, test_set = featuresets[:100], featuresets[100:]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 1.0

# %% [markdown]
# According to the result it is easy for NLTK to distinguish between Shakespeare, Blake, and Bryant.

# %% [markdown]
# ### Let's include more authors to test: Adding Busterbrown by Burgess

# %%
burgess = nltk.corpus.gutenberg.words('burgess-busterbrown.txt')
burgess = [word.lower() for word in burgess if word.isalpha()]
burgess1=[]
for i in range(16):
    burgess1.append([burgess[i*1000:(i+1)*1000],'burg'])
len(burgess)
# Out:
# 16327

# %%
sbbb=shakespeare+blake+bryant+burgess
all_words = nltk.FreqDist(w.lower() for w in sbbb)
word_features = list(all_words)[:2000] 

documents=shakespeare1+blake1+bryant1+burgess1

# %%
random.shuffle(documents)
featuresets = [(document_features(d), c) for (d,c) in documents]
len(featuresets)
# Out:
# 158

# %%
train_set, test_set = featuresets[:100], featuresets[100:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.9827586206896551

# %% [markdown]
# According to the result it is easy for NLTK to distinguish between Shakespeare, Blake, Bryant, and Burgess. The precision decreased but it is still easy to distinguish the author.

# %% [markdown]
# The most important features of the model are:

# %%
classifier.show_most_informative_features(25)
# Out:
# Most Informative Features
#           contains(down) = True             burg : shak   =     37.8 : 1.0
#          contains(birds) = True             blak : shak   =     36.0 : 1.0
#          contains(shade) = True             blak : shak   =     36.0 : 1.0
#          contains(voice) = True             blak : shak   =     36.0 : 1.0
#              contains(d) = False            brya : shak   =     35.3 : 1.0
#           contains(felt) = True             burg : shak   =     33.3 : 1.0
#        contains(started) = True             burg : shak   =     33.3 : 1.0
#         contains(behind) = True             burg : shak   =     28.9 : 1.0
#           contains(your) = False            burg : shak   =     28.9 : 1.0
#           contains(hear) = True             blak : shak   =     28.0 : 1.0
#       contains(pleasant) = True             blak : shak   =     28.0 : 1.0
#            contains(sun) = True             blak : shak   =     28.0 : 1.0
#           contains(wept) = True             blak : shak   =     28.0 : 1.0
#           contains(wild) = True             blak : shak   =     28.0 : 1.0
#            contains(own) = True             brya : shak   =     24.7 : 1.0
#          contains(brook) = True             burg : shak   =     24.4 : 1.0
#         contains(caught) = True             burg : shak   =     24.4 : 1.0
#           contains(haue) = False            brya : shak   =     23.6 : 1.0
#           contains(grew) = True             brya : shak   =     23.3 : 1.0
#           contains(bear) = True             burg : shak   =     22.7 : 1.0
#          contains(began) = True             burg : shak   =     20.0 : 1.0
#           contains(tree) = True             burg : shak   =     20.0 : 1.0
#        contains(chimney) = True             blak : shak   =     20.0 : 1.0
#          contains(cloud) = True             blak : shak   =     20.0 : 1.0
#          contains(cried) = True             burg : shak   =     20.0 : 1.0

# %% [markdown]
# - According to these characteristics we can see that a text that contains the word 'down' is 37.8 times more likely to be from Burgess than from Shakespeare.
#
# - A text that does not contain the word 'your' is 28.9 times more likely to be by Burgess than by Shakespeare.
#
#
# - We can also see that a text that contains the word 'hear', 'pleasant', 'sun', are 28 times more likely to be from Blake than from Shakespeare.
#
# - Texts containing the word 'began', 'tree', are 20 times more likely to be by Burgess than by Shakespeare.
#
# - Texts containing the word 'chimney', 'cloud', are 20 times more likely to be by Blake than by Shakespeare.

# %% [markdown]
# ## Lets include more authors to test: Adding Alice by Carroll

# %%
carroll = nltk.corpus.gutenberg.words('carroll-alice.txt')
carroll = [word.lower() for word in carroll if word.isalpha()]
carroll1=[]
for i in range(27):
    carroll1.append([carroll[i*1000:(i+1)*1000],'carr'])
len(carroll)
# Out:
# 27333

# %%
sbbbc=shakespeare+blake+bryant+burgess+carroll
all_words = nltk.FreqDist(w.lower() for w in sbbbc)
word_features = list(all_words)[:2000] 

documents=shakespeare1+blake1+bryant1+burgess1+carroll1

# %%
random.shuffle(documents)
featuresets = [(document_features(d), c) for (d,c) in documents]
len(featuresets)
# Out:
# 185

# %%
train_set, test_set = featuresets[:100], featuresets[100:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 1.0

# %% [markdown]
# According to the result it is easy for NLTK to distinguish between Shakespeare, Blake, Bryant, and Carroll.

# %%
classifier.show_most_informative_features(25)
# Out:
# Most Informative Features
#           contains(bear) = True             burg : shak   =     31.2 : 1.0
#           contains(felt) = True             burg : shak   =     31.2 : 1.0
#           contains(down) = True             blak : shak   =     31.0 : 1.0
#            contains(got) = True             carr : shak   =     30.4 : 1.0
#           contains(back) = True             burg : shak   =     27.1 : 1.0
#           contains(than) = True             burg : shak   =     27.1 : 1.0
#           contains(your) = False            burg : shak   =     27.1 : 1.0
#         contains(bright) = True             blak : shak   =     26.2 : 1.0
#          contains(voice) = True             blak : shak   =     26.2 : 1.0
#         contains(caught) = True             burg : shak   =     22.9 : 1.0
#         contains(farmer) = True             burg : shak   =     22.9 : 1.0
#        contains(started) = True             burg : shak   =     22.9 : 1.0
#           contains(tree) = True             burg : shak   =     22.9 : 1.0
#             contains(ah) = True             blak : shak   =     21.4 : 1.0
#            contains(sun) = True             blak : shak   =     21.4 : 1.0
#         contains(tender) = True             blak : shak   =     21.4 : 1.0
#           contains(wept) = True             blak : shak   =     21.4 : 1.0
#            contains(you) = False            blak : shak   =     21.4 : 1.0
#           contains(haue) = False            brya : shak   =     19.6 : 1.0
#         contains(behind) = True             burg : shak   =     18.8 : 1.0
#           contains(ears) = True             burg : shak   =     18.8 : 1.0
#           contains(hear) = True             burg : shak   =     18.8 : 1.0
#           contains(kind) = True             burg : shak   =     18.8 : 1.0
#            contains(lot) = True             burg : shak   =     18.8 : 1.0
#           contains(want) = True             burg : shak   =     18.8 : 1.0

# %% [markdown]
# According to these characteristics we can see that a text that does not contain the word 'you' is 21.4 times more likely to be from Blake than from Shakespeare.
#
# We can also see that a text that contains the word 'got' is 30.4 times more likely to be from Carroll than from Shakespeare.
#
# Texts containing the word 'sun', 'tender', are 21.4 times more likely to be from Blake than from Shakespeare.

# %% [markdown]
# ### Let's include more authors to try: Adding Ball by Chersterton

# %%
chesterson = nltk.corpus.gutenberg.words('chesterton-ball.txt')+nltk.corpus.gutenberg.words('chesterton-brown.txt')+nltk.corpus.gutenberg.words('chesterton-thursday.txt')
chesterson = [word.lower() for word in chesterson if word.isalpha()]
chesterson1=[]
for i in range(214):
    chesterson1.append([chesterson[i*1000:(i+1)*1000],'ches'])
len(chesterson)
# Out:
# 214692

# %%
sbbbcc=shakespeare+blake+bryant+burgess+carroll+chesterson
all_words = nltk.FreqDist(w.lower() for w in sbbbcc)
word_features = list(all_words)[:2000] 

documents=shakespeare1+blake1+bryant1+burgess1+carroll1+chesterson1

# %%
random.shuffle(documents)
featuresets = [(document_features(d), c) for (d,c) in documents]
len(featuresets)
# Out:
# 399

# %% [markdown]
# Since we now have 399 texts, let's increase our training set to keep it at about 25% of the corpus.

# %%
train_set, test_set = featuresets[:170], featuresets[170:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.9563318777292577

# %% [markdown]
# According to the results, it is easy for NLTK to distinguish between Shakespeare, Blake, Bryant, Carroll, and Chesterson.

# %%
classifier.show_most_informative_features(25)
# Out:
# Most Informative Features
#           contains(sing) = True             blak : ches   =     51.6 : 1.0
#          contains(sweet) = True             blak : ches   =     51.6 : 1.0
#           contains(thou) = True             blak : ches   =     51.6 : 1.0
#        contains(herself) = True             carr : ches   =     50.7 : 1.0
#        contains(chimney) = True             blak : ches   =     40.1 : 1.0
#           contains(fish) = True             burg : ches   =     40.1 : 1.0
#            contains(joy) = True             blak : ches   =     40.1 : 1.0
#          contains(quick) = True             burg : ches   =     40.1 : 1.0
#          contains(tears) = True             blak : ches   =     40.1 : 1.0
#           contains(thee) = True             blak : ches   =     40.1 : 1.0
#            contains(thy) = True             blak : ches   =     40.1 : 1.0
#           contains(haue) = False            ches : shak   =     29.2 : 1.0
#          contains(angel) = True             blak : ches   =     28.7 : 1.0
#            contains(fly) = True             blak : ches   =     28.7 : 1.0
#        contains(foolish) = True             burg : ches   =     28.7 : 1.0
#            contains(hid) = True             blak : ches   =     28.7 : 1.0
#         contains(hungry) = True             burg : ches   =     28.7 : 1.0
#           contains(like) = False            burg : ches   =     28.7 : 1.0
#        contains(meadows) = True             burg : ches   =     28.7 : 1.0
#          contains(mercy) = True             blak : ches   =     28.7 : 1.0
#       contains(pleasant) = True             blak : ches   =     28.7 : 1.0
#         contains(rabbit) = True             carr : ches   =     28.7 : 1.0
#         contains(tender) = True             blak : ches   =     28.7 : 1.0
#           contains(down) = True             carr : shak   =     28.2 : 1.0
#           contains(back) = True             burg : shak   =     26.4 : 1.0

# %% [markdown]
# According to these characteristics, we can see that a text that contains the word 'sing' is 51.6 times more likely to be from Blake than from Chesterson.
#
# We can also see that a text containing the word 'herself' is 50.7 times more likely to be from Carroll than from Chesterson.

# %% [markdown]
# ## Let's include more authors to test.

# %%
austen = nltk.corpus.gutenberg.words('austen-emma.txt')+nltk.corpus.gutenberg.words('austen-persuasion.txt')+nltk.corpus.gutenberg.words('austen-sense.txt')
austen = [word.lower() for word in austen if word.isalpha()]
austen1=[]
for i in range(69):
    austen1.append([austen[i*1000:(i+1)*1000],'aust'])
len(austen)
# Out:
# 366454

# %%
edgeworth = nltk.corpus.gutenberg.words('edgeworth-parents.txt')
edgeworth = [word.lower() for word in edgeworth if word.isalpha()]
edgeworth1=[]
for i in range(170):
    edgeworth1.append([edgeworth[i*1000:(i+1)*1000],'edge'])
len(edgeworth)
# Out:
# 170737

# %%
melville = nltk.corpus.gutenberg.words('melville-moby_dick.txt')
melville = [word.lower() for word in melville if word.isalpha()]
melville1=[]
for i in range(218):
    melville1.append([melville[i*1000:(i+1)*1000],'melv'])
len(melville)
# Out:
# 218361

# %%
whitman = nltk.corpus.gutenberg.words('whitman-leaves.txt')
whitman = [word.lower() for word in whitman if word.isalpha()]
whitman1=[]
for i in range(126):
    whitman1.append([whitman[i*1000:(i+1)*1000],'whit'])
len(whitman)
# Out:
# 126276

# %%
milton = nltk.corpus.gutenberg.words('milton-paradise.txt')
milton = [word.lower() for word in milton if word.isalpha()]
milton1=[]
for i in range(126):
    milton1.append([milton[i*1000:(i+1)*1000],'milt'])
len(milton)
# Out:
# 80493

# %%
sbbbccemswam=austen+blake+bryant+burgess+carroll+chesterson+edgeworth+milton+melville+shakespeare+whitman
all_words = nltk.FreqDist(w.lower() for w in sbbbccemswam)
word_features = list(all_words)[:2000] 

documents=austen1+blake1+bryant1+burgess1+carroll1+chesterson1+edgeworth1+milton1+melville1+shakespeare1+whitman1
len(sbbbccemswam)
# Out:
# 1343558

# %%
random.shuffle(documents)
featuresets = [(document_features(d), c) for (d,c) in documents]
len(featuresets)
# Out:
# 1108

# %%
train_set, test_set = featuresets[:320], featuresets[320:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.9758883248730964

# %% [markdown]
# According to the result it is easy for NLKT to distinguish between all the authors that we included for the model: Austen, Blake, Bryant, Burgess, Carroll, Chesterson, Edgeworth, Melville, Shakespeare, and Whitman.

# %%
classifier.show_most_informative_features(50)
# Out:
# Most Informative Features
#          contains(alice) = True             carr : ches   =     42.2 : 1.0
#       contains(children) = True             blak : melv   =     38.5 : 1.0
#           contains(mild) = True             blak : ches   =     38.5 : 1.0
#          contains(smile) = True             blak : melv   =     38.5 : 1.0
#         contains(smiles) = True             blak : ches   =     38.5 : 1.0
#         contains(sorrow) = True             blak : ches   =     38.5 : 1.0
#          contains(sweet) = True             blak : ches   =     38.5 : 1.0
#            contains(had) = False            whit : ches   =     34.0 : 1.0
#             contains(an) = False            milt : ches   =     33.9 : 1.0
#            contains(mrs) = True             aust : melv   =     33.0 : 1.0
#            contains(you) = False            milt : edge   =     31.4 : 1.0
#            contains(big) = True             burg : edge   =     31.2 : 1.0
#           contains(thou) = True             shak : edge   =     31.2 : 1.0
#          contains(until) = True             burg : edge   =     31.2 : 1.0
#            contains(isn) = True             burg : melv   =     30.8 : 1.0
#          contains(water) = True             burg : ches   =     30.8 : 1.0
#           contains(thee) = True             blak : edge   =     30.3 : 1.0
#            contains(thy) = True             blak : edge   =     30.3 : 1.0
#          contains(visit) = True             aust : ches   =     28.1 : 1.0
#          contains(angel) = True             blak : melv   =     27.5 : 1.0
#             contains(at) = False            blak : ches   =     27.5 : 1.0
#         contains(beside) = True             blak : melv   =     27.5 : 1.0
#         contains(breast) = True             blak : ches   =     27.5 : 1.0
#          contains(crown) = True             blak : ches   =     27.5 : 1.0
#        contains(delight) = True             blak : melv   =     27.5 : 1.0
#           contains(glad) = True             carr : melv   =     27.5 : 1.0
#           contains(harm) = True             blak : melv   =     27.5 : 1.0
#            contains(him) = False            blak : ches   =     27.5 : 1.0
#            contains(joy) = True             blak : ches   =     27.5 : 1.0
#       contains(laughing) = True             blak : melv   =     27.5 : 1.0
#          contains(queen) = True             carr : ches   =     27.5 : 1.0
#          contains(river) = True             blak : melv   =     27.5 : 1.0
#          contains(shade) = True             blak : melv   =     27.5 : 1.0
#          contains(tears) = True             blak : melv   =     27.5 : 1.0
#         contains(tender) = True             blak : melv   =     27.5 : 1.0
#           contains(this) = False            blak : ches   =     27.5 : 1.0
#             contains(up) = False            shak : ches   =     25.9 : 1.0
#           contains(soul) = True             whit : edge   =     25.7 : 1.0
#           contains(like) = False            milt : ches   =     25.6 : 1.0
#           contains(ship) = True             melv : edge   =     24.9 : 1.0
#          contains(enter) = True             shak : melv   =     24.8 : 1.0
#              contains(d) = True             whit : milt   =     24.3 : 1.0
#          contains(brown) = True             burg : edge   =     24.3 : 1.0
#           contains(hath) = True             shak : edge   =     24.3 : 1.0
#          contains(thing) = True             aust : milt   =     24.0 : 1.0
#           contains(bear) = True             burg : ches   =     23.8 : 1.0
#             contains(if) = False            whit : ches   =     23.3 : 1.0
#             contains(er) = True             blak : ches   =     23.1 : 1.0
#              contains(o) = True             blak : ches   =     23.1 : 1.0
#           contains(some) = False            blak : melv   =     23.1 : 1.0

# %% [markdown]
# According to these characteristics we can see that a text that contains the word 'children' is 38.5 times more likely to be from Blake than from Melville.
#
# We can also see that a text that contains the word 'glad' is 27.5 times more likely to be from Carroll than from Melville.

# %% [markdown]
# [https://www.youtube.com/watch?v=lRxMWDj8QWw](https://www.youtube.com/watch?v=lRxMWDj8QWw)
